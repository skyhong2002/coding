# %%
#AC

'''
import sys
import codecs
sys.stdout = codecs.getwriter("utf-8")(sys.stdout.detach())
sys.stdin = codecs.getreader("utf-8")(sys.stdin.detach())
'''

article = input()
article = article.replace(" 陳刀", "XD")
article = article.replace("陳刀", " 陳刀")
article = article.replace("XD", " 陳刀")
print(article)
# Out:
# 陳力陳 陳刀 陳刀陳力
