# %%
#AC

defined = input()
defined = defined.split("/")

string = input()
string = string.split("/")

yy = string[defined.index("yy")]
mm = string[defined.index("mm")]
dd = string[defined.index("dd")]

print(yy + "/" + mm + "/" + dd)
# Out:
# 11266/7122/87
