# %%
#AC

record = list(map(int, input().split()))
expenditure = 0
income = 0

for i in range(0, len(record), 1):
    if record[i] > 0:
        income += record[i]
    else:
        expenditure += record[i] 

print(income)
print(expenditure)
# Out:
# 10
# 0
