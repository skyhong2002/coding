# %%
peoples = []
while True:
    log = input()
    if log == "END":
        break
    a, b = log.split()
    peoples.append([b, a])
    
peoples.sort()
peoples.reverse()

for p in peoples:
    print(p[1])
# Out:
# 中二
# 陳刀

# %%
陳刀 0.09
中二 0.87
陳棒 0.01
中ㄧ 0.21
END

# %%
peoples
# Out:
# [['0.87', '中二'], ['0.21', '中ㄧ'], ['0.09', '陳刀'], ['0.01', '陳棒']]
