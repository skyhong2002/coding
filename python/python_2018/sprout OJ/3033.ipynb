# %%
#AC

A = list(map(int, input().split()))
X = int(input())
cnt = 0
for i in range(len(A)):
    for j in range(i + 1, len(A)):
        if (A[i] + A[j]) == X:
            cnt += 1
print(cnt)
# Out:
# 15
