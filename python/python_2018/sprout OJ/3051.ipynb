# %%
#單次AC
user = {}
item = {}
timestamp = {}
while True:
    log = input()
    if log == "END":
        break

    u, i, r, t = log.split()

    if u not in user:
        user[u] = 0
    
    if i not in item:
        item[i] = 0
        
    if t not in timestamp:
        timestamp[t] = 0
        
print(len(user))
print(len(item))
print(len(timestamp))
# Out:
# 3
# 4
# 5

# %%
周中ㄧ 西瓜 YES 2016-03-21
周中二 西瓜籽 NO  2016-03-22
周中三 世界第一簡單陳刀學 YES 2016-03-23
周中ㄧ 西瓜籽 YES 2016-03-24
周中二 陳刀教你的101件事 YES 2016-03-25
END

# %%
user
# Out:
# {}
