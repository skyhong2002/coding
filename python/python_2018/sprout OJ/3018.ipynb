# %%
x = int(input())
[print('Yes') if x % i == 0 else print('Rilak87') for i in range(2, x)]
# Out:
# 87
# Rilak87
# Yes
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Yes
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# Rilak87
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
# ...
