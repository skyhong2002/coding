# %%
'''
f = open('test.txt', 'r')
s = f.read()
f.close()
'''
s = "start by d012g what'5 2ece55ary; the2 d0 what'5 p0551ble; a2d 5udde2ly y0u are d012g the 1mp0551ble."

#輸入

a = s.replace('0', 'o')
b = a.replace('1', 'i')
c = b.replace('2', 'n')
d = c.replace('5', 's')

ans = d

print(ans)

f = open(test2.txt, w)
f.write()
# Out:
# start by doing what's necessary; then do what's possible; and suddenly you are doing the impossible.
